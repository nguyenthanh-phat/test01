# %% [markdown]
# # Thuật toán và cách biểu diễn thuật toán
#
# ### Lập trình
#
# Lập trình là gì?

# %% [markdown]
# Lập trình là đưa ra những câu lệnh để máy tính thực hiện.
#
# Đưa ra câu lệnh A, trước câu lệnh B thì câu lệnh A sẽ được thực hiện trước.

# %% [markdown]
# ### Thuật toán
#
# Thuật toán là gì?

# %% [markdown]
# Thuật toán là những câu lệnh được đưa ra để giải quyết một vấn đề nào đó.

# %% [markdown]
# ### Mã gỉả
#
# #### Khái niệm:
#
# Mã giả được viết với ngôn ngữ tự nhiên một thuật toán nào đó dùng để giải quyết một vấn đề lập trình.
#
# Mã giả được quy ước chung theo từng nơi làm việc.
#
# Ví dụ:
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Mã giả:</b>

# %% [raw]
# nếu đói:
#     nhập ( "tên món ăn" )
# nếu (món còn):
#     đặt (đồ ăn)
# Ngược lại:
#     nếu (món hết):
#         đặt (cơm sườn)
# Ngược lại:
#     đi ngủ

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Mã giả:</b>

# %% [raw]
# nhap ('số a')
# Nếu (a lớn 10):
#     in ra('đúng')
# Ngược lại:
#     in ra ('sai')
#
# so = int(input('nhập số a: '))
# if so > 10:
#     print('True')
# else:
#  print('False')

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Mã giả:</b>

# %% [raw]
# nhập (số a)
# nếu a == 0
#     in (a là số 0)
# ngược lại:
#     nếu (a > 0):
#         in (a là số dương)
#     ngược lại:
#         in (a là số âm)
#
# so = int(input('nhập số a: '))
# if so == 0:
#     print('số a là số không âm không dương')
# elif so < 0:
#     print('True')
# else:
#  print('False')

# %% [markdown]
# ### Lưu đồ giải thuật
#
# Lưu đồ giải thuật là một thuật toán được biểu diễn với dạng lưu đồ
#
# Công cụ vẽ lưu đồ giải thuật: https://draw.io/
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:69018d7c-433d-44dc-8428-37395202ad70.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:23a85747-0197-4ceb-ac0f-52d682fb6ac1.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:1b96702a-e78a-4733-b95b-312f7b488d01.png)

# %% [markdown]
# ### Bài tập
#
# <b>Đề bài</b>
#
# Nhập vào nhiệt độ C, chuyển sang độ F rồi in ra màn hình
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (nhiệt độ C):
# Độ F = (nhiệt độ C)*(9/5) + 32
# In ra (Độ F)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:e02b4ffa-a8c7-4268-9677-832c8e1589a6.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương tháng này, nếu lương tháng này nhiều hơn 2 triệu thì trừ đi 10% thuế, nếu không thì không trừ.
#
# Hãy tính và in ra lương thực nhận được
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (lương tháng)
# Nếu (lương tháng) > 2 triệu:
#     lương thực = lương tháng - (lương tháng)*10%
# Ngược lại:
#     lương thực = lương tháng
# In lương thực

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:e24ba058-e517-4bc0-ab48-e3f67182c742.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương thực nhận được tháng này, nếu lương ít hơn 10 triệu, đưa hết cho vợ, nếu lương nhiều hơn 10 triệu, vợ cho 10% lương
#
# Hãy tính và in ra màn hình phần lương mình được nhận
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (lương)
# Nếu (lương) <= 10 triệu:
#     lương  = lương*0
# In (lương*10%)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:1bce4fcd-6b6c-45fb-b2e8-a8babb2c3b3a.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào số điểm văn và điểm toán, tính và in ra điểm trung bình, nếu điểm trung bình lớn hơn 8 thì in ra dòng chữ Học sinh giỏi, ngược lại thì in ra dòng chữ Không phải học sinh giỏi
#
# <b>Mã giả:</b>

# %% [raw]
# nhập (điểm văn)
# nhập (điểm toán)
# điểm tb = ((điểm văn) + (điểm toán)) / 2
# nếu điểm tb > 8:
# in (hsg)
# ngược lại:
# in (ko là hsg)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:adf68c78-49fb-4d1d-b43b-43660991f8a8.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra xem số đó có chia hết cho 5 hay không
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (số)
# nếu (số)% 5 == 0:
#     in (đúng)
# ngược lại:
#     in (sai)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:51439a70-ef9e-49f2-a455-d8eb936a6331.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào điểm số, nếu điểm số lớn hơn hoặc bằng 8, in ra dòng chữ Học sinh giỏi, nếu điểm số bé hơn 8 và lớn hơn hoặc bằng 6, in ra dòng chữ chữ học sinh Khá, ngược lại in ra dòng chữ Học sinh trung bình
#
# <b>Mã giả:</b>

# %% [raw]
# nhập (điểm tb)
# nếu điểm tb >= 8:
#     In (Hsg)
# ngược lại:
#     nếu điểm tb >= 6:
#         In (hsk)
#     ngược lại:
#         in hstb

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:da8b5700-1349-4dbe-b9c4-8c51e909b48b.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra tính chẳn lẻ và số đó có lớn hơn 10 hay không. (in ra 4 trường hợp: chẳn lớn hơn 10, lẻ lớn hơn 10, chẳn bé hơn hoặc bằng 10, lẻ bé hơn 10)
#
# <b>Mã giả:</b>

# %% [raw]
# nhập(n)
# nếu n%2 == 0:
#     nếu n > 10:
#         in (chẳn lớn hơn 10)
#     ngược lại:
#         in ra (chẳn bé hơn hoặc bằng 10)
# ngược lại:
#     nếu n > 10:
#         in (lẻ lớn hơn 10)
#     ngược lại:
#         in (lẻ bé hơn 10)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:428220b3-442c-4f3b-87be-d6b71b54f33c.png)
